# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data = np.arange(10)
data
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

plt.plot(np.random.randn(50).cumsum(), 'k--') #black dashed line
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from numpy.random import randn
fig = plt.figure()
plt.plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],rotation=30, fontsize='small')
ax.set_title('Babys first matplotlib Plot')
ax.set_xlabel('Stages')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')
ax.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008-2009 financial crisis')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-55-0f569e3d3ba5> in <module>()
#       6 ax = fig.add_subplot(1, 1, 1)
#       7
# ----> 8 data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
#       9 spx = data['SPX']
#      10
#
# ...

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

leftleg = plt.Rectangle((0.35, 0), 0.01, 0.3, color='#FFAA4B', alpha=0.8)
rightleg = plt.Rectangle((0.55, 0), 0.01, 0.27, color='#FFAA4B', alpha=0.8)
body = plt.Circle((0.5, 0.5), 0.25, color='#FFE87E', alpha=0.9)
eye = plt.Circle((0.6, 0.6), 0.05, color='#000000', alpha=0.9)
shine = plt.Circle((0.62, 0.63), 0.02, color='#FFFFFF', alpha=1)
beak = plt.Polygon([[0.9, 0.5], [0.7, 0.35], [0.7, 0.65]],
                   color='#FFAA4B', alpha=0.8)

ax.add_patch(leftleg)
ax.add_patch(rightleg)
ax.add_patch(body)
ax.add_patch(eye)
ax.add_patch(shine)
ax.add_patch(beak)
ticks = ax.set_xticks([0, 0.5, 1])
labels = ax.set_xticklabels(['cute', 'cuter', 'cutest'],rotation=45, fontsize='medium')
ticks = ax.set_yticks([0, 0.5, 1])
labels = ax.set_yticklabels(['egg', 'chick', 'adult'],rotation=45, fontsize='medium')
plt.ylabel('Chicken Age')
plt.xlabel('Chicken Adorableness')
ax.set_title('Peep Peep')
plt.savefig('chickie.svg')



#font_options = {'family' : 'monospace',
#                'weight' : 'bold',
#                'size'   : 'small'}
#plt.rc('font', **font_options)
# Out:
# <img src="data:image/png;base64,..." width="654">

# %%
fig = plt.figure()
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#fig = plt.figure()
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0), columns=['A', 'B', 'C', 'D'], index=np.arange(0, 100, 10))
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0], color='k', alpha=0.7)
data.plot.barh(ax=axes[1], color='k', alpha=0.7)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.DataFrame(np.random.rand(6, 4),index=['one', 'two', 'three', 'four', 'five', 'six'],columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.134811  0.628232  0.574390  0.849652
# two    0.784319  0.572474  0.206124  0.066707
# three  0.538568  0.811657  0.572977  0.907603
# four   0.130163  0.802263  0.996313  0.372906
# five   0.719326  0.903541  0.606465  0.299033
# six    0.459874  0.028840  0.837720  0.954679

# %%
df.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tips = pd.read_csv('examples/tips.csv')
tips.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-86-87f6ba59e58f> in <module>()
# ----> 1 tips = pd.read_csv('examples/tips.csv')
#       2 tips.head()
#
# ...

# %%
patch(sin(a),cos(a),1:length(a),'FaceColor','interp')
axis equal
# Out:
#   File "<ipython-input-117-011030f70578>", line 1
#     patch(sin(a),cos(a),1:length(a),'FaceColor','interp')
#                          ^
# SyntaxError: invalid syntax

# %%
#try this later! looks cool

#conda install bokeh

import numpy as np

from bokeh.plotting import figure, show, output_file

N = 500
x = np.linspace(0, 10, N)
y = np.linspace(0, 10, N)
xx, yy = np.meshgrid(x, y)
d = np.sin(xx)*np.cos(yy)

p = figure(x_range=(0, 10), y_range=(0, 10),
           tooltips=[("x", "$x"), ("y", "$y"), ("value", "@image")])

# must give a vector of image data for image parameter
p.image(image=[d], x=0, y=0, dw=10, dh=10, palette="Spectral11")

output_file("image.html", title="image.py example")

show(p)  # open a browser
# Out:
#   File "<ipython-input-2-86e4909171b5>", line 1
#     conda install bokeh
#                 ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import pandas as pd
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

axes=(ax1,ax2,ax3,ax4)

eye = plt.Circle((0.5, 0.5), 0.05, color='#000000', alpha=0.9)
eye2 = plt.Circle((0.5, 0.5), 0.05, color='#000000', alpha=0.9)
smile1=patches.Arc((1,.9),1,1,theta1=180,theta2=270, linewidth = 10)
smile2=patches.Arc((0,.9),1,1,theta1=270,theta2=360, linewidth = 10)

ax1.add_patch(eye)
ax2.add_patch(eye2)
ax3.add_patch(smile1)
ax4.add_patch(smile2)

plt.subplots_adjust(wspace=0, hspace=0)
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

#leftleg = plt.Rectangle((0.35, 0), 0.01, 0.3, color='#FFAA4B', alpha=0.8)

butt = plt.Circle((1, 0.4), 0.4, color='#F6F3EE', alpha=0.9)
middle = plt.Circle((1, 1.1), 0.3, color='#F6F3EE', alpha=0.9)
head = plt.Circle((1, 1.6), 0.2, color='#F6F3EE', alpha=0.9)
btn1 = plt.Circle((1, 1.2), 0.01, color='#000000', alpha=0.9)
btn2 = plt.Circle((1, 1.1), 0.01, color='#000000', alpha=0.9)
btn3 = plt.Circle((1, 1.0), 0.01, color='#000000', alpha=0.9)
eye1 = plt.Circle((0.9, 1.7), 0.01, color='#000000', alpha=0.9)
eye2 = plt.Circle((1.1, 1.7), 0.01, color='#000000', alpha=0.9)
carrot = plt.Polygon([[1.25, 1.625], [1, 1.55], [1, 1.65]],
                   color='#FFAA4B', alpha=0.8)

ax.add_patch(butt)
ax.add_patch(middle)
ax.add_patch(head)
ax.add_patch(carrot)
ax.add_patch(btn1)
ax.add_patch(btn2)
ax.add_patch(btn3)
ax.add_patch(eye1)
ax.add_patch(eye2)
ticks = ax.set_xticks([0, 1, 2])
ticks = ax.set_yticks([0, 1, 2])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
walk = pd.DataFrame(np.where(np.random.randn(3001,2) > 0, 1, -1),
                    columns=['Horizontal', 'Vertical'])
walk['Horizontal'][0] = 0
walk['Vertical'][0] = 0
walk = walk.expanding(2).sum()
walk['Horizontal'][0] = 0
walk['Vertical'][0] = 0
walk.plot(x = 'Horizontal', y = 'Vertical')
# Out:
# <img src="data:image/png;base64,..." width="640">
